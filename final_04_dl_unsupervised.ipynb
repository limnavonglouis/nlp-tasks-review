# %%
import pandas as pd, numpy as np
from langdetect import detect 
from text_token import column_token
from gensim.models import word2vec

pd.options.display.max_colwidth = 200

# %%
df = pd.read_csv('data/final_palantir_following.csv')
del df['Unnamed: 0']
df.head(2)
# Out:
#       screenName  \
# 0        AirAsia
# 1  JamesCarville
#
#                                                                                                                                                       bio
# 0  Welcome to our official Twitter account where we tweet exclusive updates, contests & our low fares. For Customer Support, kindly tweet @AirAsiaSupport
# 1                                                                         Political strategist. Ragin’ Cajun. Father of two. Louisiana Dem. Gulf Coaster.

# %%
df2 = column_token(df, 'bio')
df2.head()
# Out:
#       screenName  \
# 0        AirAsia
# 1  JamesCarville
# 2        Ferrari
# 3        AUSTRAC
# 4       fcagroup
#
#                                                                                                                                                       bio  \
# 0  Welcome to our official Twitter account where we tweet exclusive updates, contests & our low fares. For Customer Support, kindly tweet @AirAsiaSupport
# 1                                                                         Political strategist. Ragin’ Cajun. Father of two. Louisiana Dem. Gulf Coaster.
# 2                                                                          Official account of #Ferrari, \nItalian Excellence that makes the world dream.
# 3                      Official account for AUSTRAC, Australia's financial intelligence agency. For more info or to contact us, please visit our website.
# 4                                                                      Welcome to the official Fiat Chrysler Automobiles account. #fiatchrysler #fcagroup
#
#                                                                                                                                  clean_text
# 0  [welcome, official, twitter, account, tweet, exclusive, updates, contests, low, fares, customer, support, kindly, tweet, airasiasupport]
# 1                                                         [political, strategist, ragin, cajun, father, two, louisiana, dem, gulf, coaster]
# 2                                                                    [official, account, ferrari, italian, excellence, makes, world, dream]
# 3                    [official, account, austrac, australia, s, financial, intelligence, agency, info, contact, us, please, visit, website]
# 4                                                         [welcome, official, fiat, chrysler, automobiles, account, fiatchrysler, fcagroup]

# %%
from doc_embed import averaged_word_vectorizer

# %%
# Set values for various parameters
feature_size = 10    # Word vector dimensionality  
window_context = 10          # Context window size                                                                                    
min_word_count = 1   # Minimum word count                        
sample = 1e-3   # Downsample setting for frequent words

w2v_model = word2vec.Word2Vec(df2['clean_text'], size=feature_size, 
                              window=window_context, min_count = min_word_count,
                              sample=sample, iter=100)

# %%
w2v_feature_array = averaged_word_vectorizer(corpus=df2['clean_text'], model=w2v_model,
                                             num_features=feature_size)
#pd.DataFrame(w2v_feature_array)

# %%
from sklearn.cluster import KMeans

# %%
k = 4
km_model = KMeans(n_clusters=k, n_jobs=-1)
km_model.fit(pd.DataFrame(w2v_feature_array))
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=-1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
df2['labels'] = km_model.labels_

# %%
df2
# Out:
#          screenName  \
# 0           AirAsia
# 1     JamesCarville
# 2           Ferrari
# 3           AUSTRAC
# 4          fcagroup
# 5      CreditSuisse
# 6        merckgroup
# 7            Airbus
# 8   futureofprivacy
# 9   JulesPolonetsky
# 10       CenDemTech
# 11     DirectRelief
# 12         kncukier
# 13       valleyhack
# 14   codeforamerica
# 15            radar
# 16           acroll
# 17    thejointstaff
# 6            [leading, science, technology, company, healthcare, life, science, performance, materials, intended, us, ca, visitors, https, t, co, wh, xcvhme]
# 7                                                             [live, updates, people, build, world, s, best, planes, pioneer, future, aerospace, wemakeitfly]
# 8      [catalyst, privacy, leadership, scholarship, advancing, principled, data, practices, support, emerging, tech, get, updates, https, t, co, p, pvpeanfj]
# 9                                                                                [ceo, futureofprivacy, co, chair, iltechpolicy, won, t, speak, male, panels]
# 10                                    [center, democracy, technology, shaping, tech, policy, architecture, focus, rights, individual, cdteu, eu, based, team]
# 11                               [mission, improve, health, lives, people, affected, poverty, emergencies, without, regard, politics, religion, ability, pay]
# 12    [economist, s, senior, editor, coauthor, bestseller, big, data, board, director, https, t, co, ge, o, kdeu, https, t, co, ussapizeh, fellow, oxfordsbs]
# 13        [author, best, seller, elon, musk, https, t, co, ecpvupfp, writer, businessweek, host, hello, world, https, t, co, cdjbylj, z, former, scribe, nyt]
# 14                                                                                       [government, can, work, people, people, st, century, help, us, make]
# 15                                                               [o, reilly, media, s, group, blog, emerging, technologies, twitter, feed, managed, jennwebb]
# 16  [thinking, intersection, tech, society, extremely, online, strataconf, startupfest, https, t, co, nvu, c, c, il, leananalytics, fwd, conf, scaletechconf]
# 17                     [official, account, news, jointforce, gendunford, genselva, joint, staff, services, following, rts, links, endorsement, deptofdefense]
# 18                           [team, rubicon, unites, skills, experiences, military, veterans, first, responders, rapidly, deploy, emergency, response, teams]
# 19                                                                                                                         [techammer, hammer, lab, cloudera]
#
#     labels
# 0        1
# 1        2
# 2        2
# 3        1
# 4        2
# 5        1
# 6        0
# 7        1
# 8        0
# 9        1
# 10       1
# 11       1
# 12       0
# 13       0
# 14       1
# 15       1
# 16       0
# 17       1
# 18       0
# 19       3

# %%
df2.groupby('labels').count()
# Out:
#         screenName  bio  clean_text
# labels
# 0                5    5           5
# 1                4    4           4
# 2                1    1           1
# 3               10   10          10

# %% [markdown]
# # Diagnosis

# %%
from sklearn.metrics import pairwise_distances_argmin_min

# %%
cluster_number = 3

df_sub0 = df2[df2['labels'] == cluster_number]
w2v_feature_array0 = averaged_word_vectorizer(corpus=df_sub0['clean_text'], model=w2v_model,
                                             num_features=feature_size)
df_sparse0 = pd.DataFrame(w2v_feature_array0)

closest, _ = pairwise_distances_argmin_min(km_model.cluster_centers_[cluster_number].reshape(1, -1), df_sparse0)

df_sub0.iloc[closest]
# Out:
#   screenName  \
# 3    AUSTRAC
#
#                                                                                                                                   bio  \
# 3  Official account for AUSTRAC, Australia's financial intelligence agency. For more info or to contact us, please visit our website.
#
#                                                                                                                clean_text  \
# 3  [official, account, austrac, australia, s, financial, intelligence, agency, info, contact, us, please, visit, website]
#
#    labels
# 3       3

# %%
df_sub0
# Out:
#          screenName  \
# 0           AirAsia
# 3           AUSTRAC
# 5      CreditSuisse
# 7            Airbus
# 9   JulesPolonetsky
# 10       CenDemTech
# 11     DirectRelief
# 15            radar
# 17    thejointstaff
# 18      TeamRubicon
#
#                                                                                                                                                               bio  \
# 0          Welcome to our official Twitter account where we tweet exclusive updates, contests & our low fares. For Customer Support, kindly tweet @AirAsiaSupport
# 3                              Official account for AUSTRAC, Australia's financial intelligence agency. For more info or to contact us, please visit our website.
# 5                                Credit Suisse is a leading wealth manager, with strong investment banking capabilities. Also follow us on @csapac and @csschweiz
# 7                                            Live updates from the people that build the world's best planes and pioneer the future of aerospace. #WeMakeItFly ✈️
# 9                                                                                   CEO @futureofprivacy, Co-Chair @ILTechPolicy, won't speak on all male panels.
# 10       The Center for Democracy & Technology.   Shaping tech policy & architecture, with a focus on the rights of the individual. @CDTEU for our EU-based team.
# 11                    Mission: Improve the health and lives of people affected by poverty or emergencies without regard to politics, religion, or ability to pay.
# 15                                                                    O'Reilly Media's group blog about emerging technologies. Twitter feed managed by @JennWebb.
# 17  The official account for news on the #JointForce, #GenDunford, #GenSelva and Joint Staff services. (Following, RTs and links ≠ endorsement by @DeptofDefense)
# 18                          Team Rubicon unites the skills and experiences of military veterans with first responders to rapidly deploy emergency response teams.
#
#                                                                                                                                   clean_text  \
# 0   [welcome, official, twitter, account, tweet, exclusive, updates, contests, low, fares, customer, support, kindly, tweet, airasiasupport]
# 3                     [official, account, austrac, australia, s, financial, intelligence, agency, info, contact, us, please, visit, website]
# 5                 [credit, suisse, leading, wealth, manager, strong, investment, banking, capabilities, also, follow, us, csapac, csschweiz]
# 7                                            [live, updates, people, build, world, s, best, planes, pioneer, future, aerospace, wemakeitfly]
# 9                                                               [ceo, futureofprivacy, co, chair, iltechpolicy, won, t, speak, male, panels]
# 10                   [center, democracy, technology, shaping, tech, policy, architecture, focus, rights, individual, cdteu, eu, based, team]
# 11              [mission, improve, health, lives, people, affected, poverty, emergencies, without, regard, politics, religion, ability, pay]
# 15                                              [o, reilly, media, s, group, blog, emerging, technologies, twitter, feed, managed, jennwebb]
# 17    [official, account, news, jointforce, gendunford, genselva, joint, staff, services, following, rts, links, endorsement, deptofdefense]
# 18          [team, rubicon, unites, skills, experiences, military, veterans, first, responders, rapidly, deploy, emergency, response, teams]
#
#     labels
# 0        3
# 3        3
# 5        3
# 7        3
# 9        3
# 10       3
# 11       3
# 15       3
# 17       3
# 18       3

# %% [markdown]
# # Exploration

# %%
df_word2vec = pd.DataFrame(w2v_feature_array)

# %%
a = df_word2vec.iloc[7] # airbus
b = df_word2vec.iloc[0]  # air asia 

dist = np.linalg.norm(a-b)
print(dist)
# Out:
# 0.08669840375984277

# %%
a = df_word2vec.iloc[7]  # airbus
b = df_word2vec.iloc[5]  # credit suisse 

dist = np.linalg.norm(a-b)
print(dist)
# Out:
# 0.09752927886183509

# %%
abs(0.08669840375984277-0.09752927886183509)/0.09752927886183509
# Out:
# 0.11105254984337459
